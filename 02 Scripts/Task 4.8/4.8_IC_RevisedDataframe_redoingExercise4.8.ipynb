# %% [markdown]
# # 4.8 Grouping Data and Aggregating Variables
#
# 1. Aggregating data with agg() function
# 2. Aggregating data with transform()
# 3. Deriving columns with loc()

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
# Path
path = r"C:\Users\Natalia\Documents\Instacart Basket Analysis"

# %%
#import dataframe
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'merged_new_variables.pkl'))

# %%
#dropping busiest day column
df = df.drop(['busiest_day'], axis = 1)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#      busiest_days busiest_period_of_day
# 0  Regularly busy        Average orders
# 1    Slowest days        Average orders
# 2    Slowest days           Most orders
# 3    Slowest days        Average orders
# 4    Slowest days           Most orders

# %% [markdown]
# Create a subset of the first one million entries in the dataframe

# %%
#create subset of first one million entries
df_subset = df[:1000000]

print('Sample output of subset filter of merged dataset:')
df_subset.sample(5)
# Out:
# Sample output of subset filter of merged dataset:
#         order_id  user_id  order_number  orders_day_of_week  \
# 474907   3121762     5923             7                   0
# 686323     32538   189051            18                   1
# 18148    1408144   103118            62                   1
# 559030   2686764    59173            10                   5
# 572781   1683403    96935            15                   5
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 474907                 10                    22.0       10326
# 686323                 14                    15.0       35951
# 18148                  10                     1.0         196
# 559030                  8                    18.0       49235
# 572781                  8                     7.0       49235
#
#         add_to_cart_order  reordered _merge                     product_name  \
# 474907                  2          0   both              Organic Fuji Apples
# 686323                 14          1   both  Organic Unsweetened Almond Milk
# 18148                   5          1   both                             Soda
# 559030                  3          1   both              Organic Half & Half
# 572781                  1          0   both              Organic Half & Half
#
#         aisle_id  department_id  prices    price_range_loc    busiest_days  \
# 474907        24              4     2.7  Low_range product    Busiest days
# 686323        91             16     1.3  Low_range product    Busiest days
# 18148         77              7     9.0  Mid-range product    Busiest days
# 559030        53             16     1.8  Low_range product  Regularly busy
# 572781        53             16     1.8  Low_range product  Regularly busy
#
#        busiest_period_of_day
# 474907           Most orders
# 686323           Most orders
# 18148            Most orders
# 559030        Average orders
# 572781        Average orders

# %%
df_subset.shape
# Out:
# (1000000, 17)

# %% [markdown]
# # 1. Grouping data with agg() function

# %%
#group your data by product name
df.groupby('product_name')

# %% [markdown]
# Calculating the mean of the 'order_number' grouped by 'department_id'

# %%
#split the data into groups based on dep_id, then agg() by ord_number
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
#using the mean() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
#performing multiple aggregations 

print('The mean, min, and max of order_number grouped by the department_id:')
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
# The mean, min, and max of order_number grouped by the department_id:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %% [markdown]
# # 2. Aggregating Data with Transform

# %%
df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#function to display all rows
pd.options.display.max_rows = None

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
# 60   2728456       82             4                   0                 11
# 61   2653743       82             6                   4                  9
# 62   1358880       82             9                   1                 10
# 63    343588       82            10                   2                 11
# 64   3034663       82            15                   2                 11
# 65    147262       82            18                   1                 13
# 66   3144004       82            19                   2                 15
# 67   2126069       98             3                   0                  9
# 68   2210120       98             7                   5                 14
# 69    681011       98             9                   3                  9
# 70   2846344       98            11                   4                 13
# 71    747431       98            12                   6                 13
# 72   2383054       98            13                   4                 11
# 73   1993729       98            14                   5                  8
# 74   1403849      109             3                   3                 17
# 75    520620      120             1                   3                 11
# 76   3273029      120             3                   2                  8
# 77   1861943      185             2                   1                 12
# 78   2040988      195             1                   1                 14
# 79   1680569      195             8                   1                  9
# 80    276171      195            19                   5                 11
# 81   2744976      195            22                   5                 10
# 82   2781919      195            25                   1                 14
# 83   1738718      195            31                   2                  8
# 84   3058369      195            34                   3                 10
# 85   1485596      195            37                   2                 15
# 86    417035      195            40                   3                 16
# 87   1615297      195            47                   5                 10
# 88   1765587      195            52                   3                 12
# 89    745908      195            57                   4                 11
# 90   2505656      222            17                   2                 12
# 91   3268370      222            38                   5                 15
# 92   2016711      290             9                   5                 19
# 93   2706088      290            28                   6                 10
# 94   1952286      331             6                   5                 16
# 95   3226575      360             1                   5                 12
# 96   1469869      377             3                   5                 17
# 97   1927023      387             2                   4                 10
# 98    858092      420             4                   1                 19
# 99    119314      420             5                   3                 19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                     15.0         196                  1          1   both
# 2                     21.0         196                  1          1   both
# 3                     29.0         196                  1          1   both
# 4                     28.0         196                  1          1   both
# 5                     19.0         196                  1          1   both
# 6                     20.0         196                  1          1   both
# 7                     14.0         196                  2          1   both
# 8                      0.0         196                  4          1   both
# 9                     30.0         196                  1          1   both
# 10                     7.0         196                  2          0   both
# 11                     8.0         196                  6          1   both
# 12                     7.0         196                  1          1   both
# 13                     7.0         196                  1          1   both
# 14                    14.0         196                  1          1   both
# 15                     6.0         196                  3          0   both
# 16                     8.0         196                 15          1   both
# 17                     6.0         196                  1          1   both
# 18                     6.0         196                  2          0   both
# 19                     7.0         196                 17          0   both
# 20                     8.0         196                 14          1   both
# 21                     4.0         196                  9          0   both
# 22                     3.0         196                  1          1   both
# 23                     NaN         196                  4          0   both
# 24                     7.0         196                  5          1   both
# 25                     7.0         196                  3          1   both
# 26                     8.0         196                  6          1   both
# 27                     8.0         196                  5          1   both
# 28                     7.0         196                  5          1   both
# 29                     8.0         196                  4          1   both
# 30                     7.0         196                  3          1   both
# 31                     6.0         196                  7          1   both
# 32                     8.0         196                  3          1   both
# 33                     6.0         196                  4          1   both
# 34                    14.0         196                  6          1   both
# 35                     8.0         196                  4          1   both
# 36                    30.0         196                  1          1   both
# 37                     NaN         196                  1          0   both
# 38                     5.0         196                  2          1   both
# 39                     7.0         196                  2          1   both
# 40                     8.0         196                  1          1   both
# 41                     8.0         196                  2          1   both
# 42                     7.0         196                  2          1   both
# 43                     7.0         196                  1          1   both
# 44                     7.0         196                  1          1   both
# 45                     6.0         196                  1          1   both
# 46                     7.0         196                  1          1   both
# 47                     8.0         196                  1          1   both
# 48                     6.0         196                  1          1   both
# 49                     7.0         196                  1          1   both
# 50                     9.0         196                  1          1   both
# 51                     4.0         196                  1          1   both
# 52                     9.0         196                  2          1   both
# 53                     5.0         196                  2          1   both
# 54                    14.0         196                  3          1   both
# 55                    14.0         196                  1          1   both
# 56                    14.0         196                  2          0   both
# 57                    30.0         196                  1          1   both
# 58                     NaN         196                  6          0   both
# 59                     5.0         196                  2          1   both
# 60                    16.0         196                  1          1   both
# 61                    13.0         196                  5          1   both
# 62                    30.0         196                  1          1   both
# 63                     1.0         196                  1          1   both
# 64                    12.0         196                  1          1   both
# 65                     7.0         196                  1          1   both
# 66                     8.0         196                  1          1   both
# 67                    25.0         196                  7          0   both
# 68                     5.0         196                  1          1   both
# 69                    30.0         196                  1          1   both
# 70                    15.0         196                  2          1   both
# 71                    30.0         196                  4          1   both
# 72                    30.0         196                  1          1   both
# 73                     8.0         196                  2          1   both
# 74                     9.0         196                  5          0   both
# 75                     NaN         196                  2          0   both
# 76                    19.0         196                  2          1   both
# 77                    25.0         196                 10          0   both
# 78                     NaN         196                  2          0   both
# 79                     4.0         196                  2          1   both
# 80                     3.0         196                  2          1   both
# 81                     7.0         196                  2          1   both
# 82                     4.0         196                  1          1   both
# 83                     4.0         196                  2          1   both
# 84                     6.0         196                  2          1   both
# 85                     0.0         196                  2          1   both
# 86                     2.0         196                  2          1   both
# 87                     2.0         196                  2          1   both
# 88                     2.0         196                  3          1   both
# 89                     3.0         196                  3          1   both
# 90                     1.0         196                  2          0   both
# 91                     1.0         196                  6          1   both
# 92                     6.0         196                  8          0   both
# 93                     7.0         196                 16          1   both
# 94                    30.0         196                  8          0   both
# 95                     NaN         196                  1          0   both
# 96                     3.0         196                  9          0   both
# 97                    22.0         196                  3          0   both
# 98                    30.0         196                  2          0   both
# 99                    16.0         196                  2          1   both
#
#    product_name  aisle_id  department_id  prices    price_range_loc  \
# 0          Soda        77              7     9.0  Mid-range product
# 1          Soda        77              7     9.0  Mid-range product
# 2          Soda        77              7     9.0  Mid-range product
# 3          Soda        77              7     9.0  Mid-range product
# 4          Soda        77              7     9.0  Mid-range product
# 5          Soda        77              7     9.0  Mid-range product
# 6          Soda        77              7     9.0  Mid-range product
# 7          Soda        77              7     9.0  Mid-range product
# 8          Soda        77              7     9.0  Mid-range product
# 9          Soda        77              7     9.0  Mid-range product
# 10         Soda        77              7     9.0  Mid-range product
# 11         Soda        77              7     9.0  Mid-range product
# 12         Soda        77              7     9.0  Mid-range product
# 13         Soda        77              7     9.0  Mid-range product
# 14         Soda        77              7     9.0  Mid-range product
# 15         Soda        77              7     9.0  Mid-range product
# 16         Soda        77              7     9.0  Mid-range product
# 17         Soda        77              7     9.0  Mid-range product
# 18         Soda        77              7     9.0  Mid-range product
# 19         Soda        77              7     9.0  Mid-range product
# 20         Soda        77              7     9.0  Mid-range product
# 21         Soda        77              7     9.0  Mid-range product
# 22         Soda        77              7     9.0  Mid-range product
# 23         Soda        77              7     9.0  Mid-range product
# 24         Soda        77              7     9.0  Mid-range product
# 25         Soda        77              7     9.0  Mid-range product
# 26         Soda        77              7     9.0  Mid-range product
# 27         Soda        77              7     9.0  Mid-range product
# 28         Soda        77              7     9.0  Mid-range product
# 29         Soda        77              7     9.0  Mid-range product
# 30         Soda        77              7     9.0  Mid-range product
# 31         Soda        77              7     9.0  Mid-range product
# 32         Soda        77              7     9.0  Mid-range product
# 33         Soda        77              7     9.0  Mid-range product
# 34         Soda        77              7     9.0  Mid-range product
# 35         Soda        77              7     9.0  Mid-range product
# 36         Soda        77              7     9.0  Mid-range product
# 37         Soda        77              7     9.0  Mid-range product
# 38         Soda        77              7     9.0  Mid-range product
# 39         Soda        77              7     9.0  Mid-range product
# 40         Soda        77              7     9.0  Mid-range product
# 41         Soda        77              7     9.0  Mid-range product
# 42         Soda        77              7     9.0  Mid-range product
# 43         Soda        77              7     9.0  Mid-range product
# 44         Soda        77              7     9.0  Mid-range product
# 45         Soda        77              7     9.0  Mid-range product
# 46         Soda        77              7     9.0  Mid-range product
# 47         Soda        77              7     9.0  Mid-range product
# 48         Soda        77              7     9.0  Mid-range product
# 49         Soda        77              7     9.0  Mid-range product
# 50         Soda        77              7     9.0  Mid-range product
# 51         Soda        77              7     9.0  Mid-range product
# 52         Soda        77              7     9.0  Mid-range product
# 53         Soda        77              7     9.0  Mid-range product
# 54         Soda        77              7     9.0  Mid-range product
# 55         Soda        77              7     9.0  Mid-range product
# 56         Soda        77              7     9.0  Mid-range product
# 57         Soda        77              7     9.0  Mid-range product
# 58         Soda        77              7     9.0  Mid-range product
# 59         Soda        77              7     9.0  Mid-range product
# 60         Soda        77              7     9.0  Mid-range product
# 61         Soda        77              7     9.0  Mid-range product
# 62         Soda        77              7     9.0  Mid-range product
# 63         Soda        77              7     9.0  Mid-range product
# 64         Soda        77              7     9.0  Mid-range product
# 65         Soda        77              7     9.0  Mid-range product
# 66         Soda        77              7     9.0  Mid-range product
# 67         Soda        77              7     9.0  Mid-range product
# 68         Soda        77              7     9.0  Mid-range product
# 69         Soda        77              7     9.0  Mid-range product
# 70         Soda        77              7     9.0  Mid-range product
# 71         Soda        77              7     9.0  Mid-range product
# 72         Soda        77              7     9.0  Mid-range product
# 73         Soda        77              7     9.0  Mid-range product
# 74         Soda        77              7     9.0  Mid-range product
# 75         Soda        77              7     9.0  Mid-range product
# 76         Soda        77              7     9.0  Mid-range product
# 77         Soda        77              7     9.0  Mid-range product
# 78         Soda        77              7     9.0  Mid-range product
# 79         Soda        77              7     9.0  Mid-range product
# 80         Soda        77              7     9.0  Mid-range product
# 81         Soda        77              7     9.0  Mid-range product
# 82         Soda        77              7     9.0  Mid-range product
# 83         Soda        77              7     9.0  Mid-range product
# 84         Soda        77              7     9.0  Mid-range product
# 85         Soda        77              7     9.0  Mid-range product
# 86         Soda        77              7     9.0  Mid-range product
# 87         Soda        77              7     9.0  Mid-range product
# 88         Soda        77              7     9.0  Mid-range product
# 89         Soda        77              7     9.0  Mid-range product
# 90         Soda        77              7     9.0  Mid-range product
# 91         Soda        77              7     9.0  Mid-range product
# 92         Soda        77              7     9.0  Mid-range product
# 93         Soda        77              7     9.0  Mid-range product
# 94         Soda        77              7     9.0  Mid-range product
# 95         Soda        77              7     9.0  Mid-range product
# 96         Soda        77              7     9.0  Mid-range product
# 97         Soda        77              7     9.0  Mid-range product
# 98         Soda        77              7     9.0  Mid-range product
# 99         Soda        77              7     9.0  Mid-range product
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1     Slowest days        Average orders         10
# 2     Slowest days           Most orders         10
# 3     Slowest days        Average orders         10
# 4     Slowest days           Most orders         10
# 5   Regularly busy        Average orders         10
# 6     Busiest days           Most orders         10
# 7     Busiest days           Most orders         10
# 8     Busiest days           Most orders         10
# 9     Slowest days        Average orders         10
# 10    Busiest days           Most orders         22
# 11  Regularly busy           Most orders         22
# 12  Regularly busy           Most orders         22
# 13    Busiest days           Most orders         22
# 14    Busiest days           Most orders         22
# 15  Regularly busy           Most orders          9
# 16  Regularly busy           Most orders          9
# 17    Slowest days        Average orders          9
# 18    Slowest days           Most orders         33
# 19    Slowest days        Average orders         20
# 20    Slowest days           Most orders         20
# 21    Slowest days           Most orders         11
# 22    Slowest days           Most orders         11
# 23    Busiest days           Most orders         27
# 24    Busiest days           Most orders         27
# 25    Busiest days           Most orders         27
# 26  Regularly busy           Most orders         27
# 27  Regularly busy        Average orders         27
# 28    Busiest days           Most orders         27
# 29  Regularly busy           Most orders         27
# 30  Regularly busy           Most orders         27
# 31    Busiest days           Most orders         27
# 32  Regularly busy           Most orders         27
# 33  Regularly busy           Most orders         27
# 34  Regularly busy           Most orders         27
# 35    Slowest days        Average orders         27
# 36  Regularly busy           Most orders         27
# 37    Slowest days           Most orders         24
# 38    Busiest days           Most orders         24
# 39    Busiest days           Most orders         24
# 40  Regularly busy           Most orders         24
# 41    Slowest days           Most orders         24
# 42    Slowest days           Most orders         24
# 43  Regularly busy           Most orders         24
# 44  Regularly busy           Most orders         24
# 45    Busiest days           Most orders         24
# 46    Busiest days           Most orders         24
# 47  Regularly busy           Most orders         24
# 48    Busiest days           Most orders         24
# 49    Busiest days           Most orders         24
# 50    Slowest days           Most orders         24
# 51  Regularly busy           Most orders         24
# 52    Busiest days           Most orders         24
# 53    Busiest days           Most orders         24
# 54    Busiest days           Most orders         24
# 55    Busiest days           Most orders         24
# 56    Busiest days           Most orders          7
# 57  Regularly busy        Average orders          7
# 58    Slowest days           Most orders         19
# 59  Regularly busy           Most orders         19
# 60    Busiest days           Most orders         19
# 61    Slowest days           Most orders         19
# 62    Busiest days           Most orders         19
# 63  Regularly busy           Most orders         19
# 64  Regularly busy           Most orders         19
# 65    Busiest days           Most orders         19
# 66  Regularly busy           Most orders         19
# 67    Busiest days           Most orders         14
# 68  Regularly busy           Most orders         14
# 69    Slowest days           Most orders         14
# 70    Slowest days           Most orders         14
# 71  Regularly busy           Most orders         14
# 72    Slowest days           Most orders         14
# 73  Regularly busy        Average orders         14
# 74    Slowest days        Average orders          6
# 75    Slowest days           Most orders          3
# 76  Regularly busy        Average orders          3
# 77    Busiest days           Most orders          6
# 78    Busiest days           Most orders         58
# 79    Busiest days           Most orders         58
# 80  Regularly busy           Most orders         58
# 81  Regularly busy           Most orders         58
# 82    Busiest days           Most orders         58
# 83  Regularly busy        Average orders         58
# 84    Slowest days           Most orders         58
# 85  Regularly busy           Most orders         58
# 86    Slowest days           Most orders         58
# 87  Regularly busy           Most orders         58
# 88    Slowest days           Most orders         58
# 89    Slowest days           Most orders         58
# 90  Regularly busy           Most orders         70
# 91  Regularly busy           Most orders         70
# 92  Regularly busy        Average orders         51
# 93  Regularly busy           Most orders         51
# 94  Regularly busy           Most orders          8
# 95  Regularly busy           Most orders          3
# 96  Regularly busy        Average orders          3
# 97    Slowest days           Most orders          8
# 98    Busiest days        Average orders         22
# 99    Slowest days        Average orders         22

# %% [markdown]
# # Deriving Columns with loc()

# %%
#creating my flag based on values using loc()

# %%
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df.loc[df['max_order'] <= 40, 'loyalty_flag'] = 'Regular customer'

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#checking output of certain columns
df[['user_id', 'loyalty_flag', 'max_order']].sample(60)
# Out:
#           user_id      loyalty_flag  max_order
# 12886767    59819    Loyal customer         99
# 28088431   181652    Loyal customer         48
# 26163894    68415  Regular customer         15
# 11419211   180789      New customer          7
# 9710362     40821  Regular customer         23
# 19138353   113792      New customer          7
# 32284973    65231    Loyal customer         48
# 6476678    128839  Regular customer         15
# 14210457   102999    Loyal customer         50
# 8592945     92301    Loyal customer         64
# 27067581    43365    Loyal customer         88
# 1717684     82084      New customer          7
# 28104660    59742    Loyal customer         99
# 15801850    39518  Regular customer         25
# 32398324   168010      New customer          5
# 460438      64597  Regular customer         15
# 9569309     53089      New customer          4
# 896985      96748    Loyal customer         50
# 30237230   202353  Regular customer         18
# 22752614    37093    Loyal customer         57
# 28984727   187726    Loyal customer         46
# 30581466     8290    Loyal customer         43
# 23070678   162039  Regular customer         40
# 16898408   196226  Regular customer         15
# 31127280    60650    Loyal customer         71
# 27388384   122800  Regular customer         30
# 17233569   163522      New customer          4
# 26813753   154650      New customer          6
# 30061276    59606      New customer         10
# 27776919    36845  Regular customer         18
# 24584125    88996    Loyal customer         58
# 21661914    68407  Regular customer         22
# 10741703   146933  Regular customer         25
# 22736293    39779    Loyal customer         42
# 8768427     34531    Loyal customer         47
# 5200436    132753  Regular customer         14
# 15218328   163606    Loyal customer         58
# 884649      27477  Regular customer         14
# 27431247   114701    Loyal customer         50
# 8724525    157585    Loyal customer         46
# 16328013    61692  Regular customer         32
# 17952119    62857  Regular customer         19
# 23317713   203081  Regular customer         26
# 24814566   177943    Loyal customer         45
# 17467775    91759  Regular customer         26
# 16604698    54610      New customer          3
# 761103      79372    Loyal customer         74
# 11994255   151378    Loyal customer         61
# 743621      60005  Regular customer         11
# 5692510    185097      New customer          4
# 3765268    181572  Regular customer         17
# 26683706   158880      New customer          7
# 17000676     9230  Regular customer         17
# 19358059   127946    Loyal customer         62
# 19374746    36163    Loyal customer         43
# 2084699     79253  Regular customer         38
# 19875524    75664    Loyal customer         99
# 31819330   144118      New customer          7
# 29382147    30798    Loyal customer         55
# 31101854    27910  Regular customer         11

# %%
#export dataframe 
df.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'full_merged4.pkl'))
